# %% [markdown]
# <a href="https://colab.research.google.com/github/george123-cloud/finalProject/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
import kagglehub
path = kagglehub.dataset_download("shivamb/netflix-shows")
print(path)
# Out:
# Using Colab cache for faster access to the 'netflix-shows' dataset.
# /kaggle/input/netflix-shows

# %%
import pandas as pd

url = path+"/netflix_titles.csv"
df = pd.read_csv(url)
#pd.set_option("display.max_columns", None)

print(df.columns[1:5])
# Out:
# Index(['type', 'title', 'director', 'cast'], dtype='object')

# %%
import kagglehub
path = kagglehub.dataset_download("nasa/kepler-exoplanet-search-results")

url2 = path+"/cumulative.csv"
df2 = pd.read_csv(url2)
#pd.set_option("display.max_columns", None)

print(df2.describe())
# Out:
# Using Colab cache for faster access to the 'kepler-exoplanet-search-results' dataset.
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.188206       0.231598
# std    2761.033321  2.653459e+06     0.476928       0.390897       0.421875
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000       1.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# ...

# %%
mylist = [1,2,3,4]
print("list length : " + str(len((mylist))))
# Out:
# list length : 4
